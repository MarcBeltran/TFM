# %%
import pandas as pd
import numpy as np
from PIL import Image
import glob

# %%
images = []

for filename in glob.glob('data/train/*.jpg'):
    im=Image.open(filename)
    images.append(im)
    
masks = []

for filename in glob.glob('data/train/*.png'):
    im=Image.open(filename)
    masks.append(im)
# Out:
# CPU times: user 659 ms, sys: 189 ms, total: 847 ms
# Wall time: 974 ms

# %%
masks[0]
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x1024 at 0x7F403688F588>
